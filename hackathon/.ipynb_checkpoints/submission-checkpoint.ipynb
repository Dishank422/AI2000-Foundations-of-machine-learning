# %%
import pandas as pd
import numpy as np
import xgboost as xgb
# from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from pandas.tseries.holiday import *
cal = USFederalHolidayCalendar()

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
# np.random.seed(422)
# t = pd.read_csv("train.csv")
# train, test = train_test_split(t, test_size=0.2)
# Out:
# /home/dishank/.local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
train.drop(["Report Number","Local Case Number","Agency Name","Off-Road Description","Municipality","Circumstance","Vehicle ID","Driverless Vehicle", "Latitude", "Longitude","Municipality","Person ID","Vehicle Going Dir", "Vehicle Continuing Dir", "Vehicle Make", "Vehicle Model", "Drivers License State", "Road Name","Non-Motorist Substance Abuse","Cross-Street Name"], axis=1, inplace=True)

train["Crash Date/Time"] = pd.to_datetime(train["Crash Date/Time"])

train["hour"] = train["Crash Date/Time"].dt.hour
train["dayofweek"] = train["Crash Date/Time"].dt.dayofweek

holidays = cal.holidays(start=train['Crash Date/Time'].dt.date.min(), end=train['Crash Date/Time'].dt.date.max())
train['holiday'] = train['Crash Date/Time'].dt.date.astype('datetime64').isin(holidays).astype('uint8')

train.drop("Crash Date/Time", axis=1, inplace=True)

train['Location'] = train['Location'].str.replace(',',' ')
train[['l1', 'l2']] = train.Location.str.split(' ', expand = True ).astype(float)
train.drop(columns = ['Location'], inplace = True)

train["Parked Vehicle"] = train["Parked Vehicle"].astype("category").cat.codes
train["ACRS Report Type"] = train["ACRS Report Type"].astype("category").cat.codes

train["Vehicle First Impact Location"].fillna("UNKNOWN", inplace=True)
train["Vehicle Second Impact Location"].fillna("UNKNOWN", inplace=True)
train["Vehicle First Impact Location"] = train["Vehicle First Impact Location"].astype("category").cat.codes
train["Vehicle Second Impact Location"] = train["Vehicle Second Impact Location"].astype("category").cat.codes

train["Vehicle Movement"].fillna("UNKNOWN", inplace=True)
train["Vehicle Movement"] = train["Vehicle Movement"].astype("category").cat.codes

train["Equipment Problems"].fillna("UNKNOWN", inplace=True)
train["Equipment Problems"][3] = "NOT STREPPED RIGHT"
train["Equipment Problems"][8] = "SIZE/TYPE IMPROPER"
train["Equipment Problems"] = train["Equipment Problems"].astype("category").cat.codes

train["Vehicle Body Type"].fillna("UNKNOWN", inplace=True)
train["Vehicle Body Type"] = train["Vehicle Body Type"].astype("category").cat.codes

train["Vehicle Damage Extent"].fillna("UNKNOWN", inplace=True)
train["Vehicle Damage Extent"] = train["Vehicle Damage Extent"].astype("category").cat.codes

train["Cross-Street Type"].fillna("UNKNOWN", inplace=True)
train["Cross-Street Type"] = train["Cross-Street Type"].astype("category").cat.codes

train["Related Non-Motorist"].fillna("NIL", inplace=True)
train["Related Non-Motorist"] = train["Related Non-Motorist"].astype("category").cat.codes

train["Route Type"].fillna("UNKNOWN", inplace=True)
train["Route Type"] = train["Route Type"].astype("category").cat.codes

train["Injury Severity"] = train["Injury Severity"].astype("category").cat.codes

train["Traffic Control"].fillna("UNKNOWN", inplace=True)
train["Traffic Control"] = train["Traffic Control"].astype("category").cat.codes

train["Light"].fillna("UNKNOWN", inplace=True)
train["Light"] = train["Light"].astype("category").cat.codes

train["Surface Condition"].fillna("UNKNOWN", inplace=True)
train["Surface Condition"] = train["Surface Condition"].astype("category").cat.codes

train["Collision Type"].fillna("UNKNOWN", inplace=True)
train["Collision Type"] = train["Collision Type"].astype("category").cat.codes

train["Weather"].fillna("UNKNOWN", inplace=True)
train["Weather"] = train["Weather"].astype("category").cat.codes

train["Driver Substance Abuse"].fillna("UNKNOWN", inplace=True)
train["Driver Substance Abuse"] = train["Driver Substance Abuse"].astype("category").cat.codes

train.drop("Vehicle Year", axis=1,inplace=True)

train_target = train["Fault"]
train.drop("Fault", axis=1, inplace=True)
# Out:
# /tmp/ipykernel_144276/1778239375.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["Equipment Problems"][3] = "NOT STREPPED RIGHT"
# /tmp/ipykernel_144276/1778239375.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train["Equipment Problems"][8] = "SIZE/TYPE IMPROPER"

# %%
keys = test["Id"]
test.drop("Id",axis=1,inplace=True)

test.drop(["Report Number","Local Case Number","Agency Name","Off-Road Description","Municipality","Circumstance","Vehicle ID","Driverless Vehicle", "Latitude", "Longitude","Municipality","Person ID","Vehicle Going Dir", "Vehicle Continuing Dir", "Vehicle Make", "Vehicle Model", "Drivers License State", "Road Name","Non-Motorist Substance Abuse","Cross-Street Name"], axis=1, inplace=True)

test["Crash Date/Time"] = pd.to_datetime(test["Crash Date/Time"])

test["hour"] = test["Crash Date/Time"].dt.hour
test["dayofweek"] = test["Crash Date/Time"].dt.dayofweek

holidays = cal.holidays(start=test['Crash Date/Time'].dt.date.min(), end=test['Crash Date/Time'].dt.date.max())
test['holiday'] = test['Crash Date/Time'].dt.date.astype('datetime64').isin(holidays).astype('uint8')

test.drop("Crash Date/Time", axis=1, inplace=True)

test['Location'] = test['Location'].str.replace(',',' ')
test[['l1', 'l2']] = test.Location.str.split(' ', expand = True ).astype(float)
test.drop(columns = ['Location'], inplace = True)

test["Parked Vehicle"] = test["Parked Vehicle"].astype("category").cat.codes
test["ACRS Report Type"] = test["ACRS Report Type"].astype("category").cat.codes

test["Vehicle First Impact Location"].fillna("UNKNOWN", inplace=True)
test["Vehicle Second Impact Location"].fillna("UNKNOWN", inplace=True)
test["Vehicle First Impact Location"] = test["Vehicle First Impact Location"].astype("category").cat.codes
test["Vehicle Second Impact Location"] = test["Vehicle Second Impact Location"].astype("category").cat.codes

test["Vehicle Movement"].fillna("UNKNOWN", inplace=True)
test["Vehicle Movement"] = test["Vehicle Movement"].astype("category").cat.codes

test["Equipment Problems"].fillna("UNKNOWN", inplace=True)
test["Equipment Problems"] = test["Equipment Problems"].astype("category").cat.codes

test["Vehicle Body Type"].fillna("UNKNOWN", inplace=True)
test["Vehicle Body Type"] = test["Vehicle Body Type"].astype("category").cat.codes

test["Vehicle Damage Extent"].fillna("UNKNOWN", inplace=True)
test["Vehicle Damage Extent"] = test["Vehicle Damage Extent"].astype("category").cat.codes

test["Cross-Street Type"].fillna("UNKNOWN", inplace=True)
test["Cross-Street Type"] = test["Cross-Street Type"].astype("category").cat.codes

test["Related Non-Motorist"].fillna("NIL", inplace=True)
test["Related Non-Motorist"] = test["Related Non-Motorist"].astype("category").cat.codes

test["Route Type"].fillna("UNKNOWN", inplace=True)
test["Route Type"] = test["Route Type"].astype("category").cat.codes

test["Injury Severity"] = test["Injury Severity"].astype("category").cat.codes

test["Traffic Control"].fillna("UNKNOWN", inplace=True)
test["Traffic Control"] = test["Traffic Control"].astype("category").cat.codes

test["Light"].fillna("UNKNOWN", inplace=True)
test["Light"] = test["Light"].astype("category").cat.codes

test["Surface Condition"].fillna("UNKNOWN", inplace=True)
test["Surface Condition"] = test["Surface Condition"].astype("category").cat.codes

test["Collision Type"].fillna("UNKNOWN", inplace=True)
test["Collision Type"] = test["Collision Type"].astype("category").cat.codes

test["Weather"].fillna("UNKNOWN", inplace=True)
test["Weather"] = test["Weather"].astype("category").cat.codes

test["Driver Substance Abuse"].fillna("UNKNOWN", inplace=True)
test["Driver Substance Abuse"] = test["Driver Substance Abuse"].astype("category").cat.codes

test.drop("Vehicle Year", axis=1,inplace=True)

# test_target = test["Fault"]
# test.drop("Fault", axis=1, inplace=True)

# %%
# reg = GradientBoostingClassifier(n_estimators = 500, max_depth=6)
# reg.fit(train, train_target)

# preds = reg.predict(test)
# submission = pd.DataFrame({'Id': keys, 'Fault':preds})
# submission.to_csv('sample_submission.csv',index=False)

# %%
"""
dtrain = xgb.DMatrix(train, label=train_target)
# param = {'max_depth': 8, 'eta': 0.06, 'objective': 'binary:hinge'}
param = {'booster':'dart', 'max_depth':6,'eta': 0.06, 'objective': 'binary:hinge', 'rate_drop':0.01, 'sample_type':'weighted'}
dtest = xgb.DMatrix(test)
bst = xgb.train(param, dtrain, 1000)
preds = np.array(bst.predict(dtest),dtype=int)
submission = pd.DataFrame({'Id': keys, 'Fault':preds})
submission.to_csv('sample_submission.csv',index=False)
"""
# Out:
# "\ndtrain = xgb.DMatrix(train, label=train_target)\n# param = {'max_depth': 8, 'eta': 0.06, 'objective': 'binary:hinge'}\nparam = {'booster':'dart', 'max_depth':6,'eta': 0.06, 'objective': 'binary:hinge', 'rate_drop':0.01, 'sample_type':'weighted'}\ndtest = xgb.DMatrix(test)\nbst = xgb.train(param, dtrain, 1000)\npreds = np.array(bst.predict(dtest),dtype=int)\nsubmission = pd.DataFrame({'Id': keys, 'Fault':preds})\nsubmission.to_csv('sample_submission.csv',index=False)\n"

# %%
# import lightgbm as lgb
# dtrain = lgb.Dataset(train, label=train_target)
# param = {'verbose':-1,'task':'train','boosting':'dart','learning_rate': 0.06, 'objective': 'binary', 'rate_drop':0.02,'num_leaves':52,'metric':'binary_logloss'}
# bst = lgb.train(param, dtrain, 1000)
# preds = bst.predict(test)
# preds = preds.round(0)
# preds = preds.astype(int)
# submission = pd.DataFrame({'Id': keys, 'Fault':preds})
# submission.to_csv('sample_submission.csv',index=False)
# accuracy_score(test_target, preds)

# %%
# from flaml import AutoML
# automl = AutoML()
# automl.fit(train, train_target, task="classification", time_budget=500)
# preds = automl.predict(test)
# submission = pd.DataFrame({'Id': keys, 'Fault':preds})
# submission.to_csv('sample_submission.csv',index=False)
# accuracy_score(test_target, preds)
# Out:
# [flaml.automl: 11-14 00:51:02] {1485} INFO - Data split method: stratified
# [flaml.automl: 11-14 00:51:02] {1489} INFO - Evaluation method: cv
# [flaml.automl: 11-14 00:51:02] {1540} INFO - Minimizing error metric: 1-roc_auc
# [flaml.autom
	best estimator lgbm's best error=0.0932
# [flaml.automl: 11-14 00:51:07] {1826} INFO - iteration 14, current learner rf
# [flaml.automl: 11-14 00:51:08] {2023} INFO -  at 6.5s,	estimator rf's best error=0.1436,	best estimator lgbm's best error=0.0932
# [flaml.automl: 11-14 00:51:08] {1826} INFO - iteration 15, current learner xgboost
# [flaml.automl: 11-14 00:51:09] {2023} INFO -  at 6.8s,	estimator xgboost's best error=0.1862,	best estimator lgbm's best error=0.0932
# [flaml.automl: 11-14 00:51:09] {1826} INFO - iteration 16, current learner lgbm
# [flaml.automl: 11-14 00:51:09] {2023} INFO -  at 7.1s,	estimator lgbm's best error=0.0932,	best estimator lgbm's best error=0.0932
# [flaml.automl: 11-14 00:51:09] {1826} INFO - iteration 17, current learner extra_tree
# [flaml.automl: 11-14 00:51:10] {2023} INFO -  at 7.7s,	estimator extra_tree's best error=0.1481,	best estimator lgbm's best error=0.0932
# [flaml.automl: 11-14 00:51:10] {1826} INFO - iteration 18, current learner lgbm
# [flaml.automl: 11-14 00:51:11] {2023} INFO -  at 9.4s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:11] {1826} INFO - iteration 19, current learner xgboost
# [flaml.automl: 11-14 00:51:12] {2023} INFO -  at 9.7s,	estimator xgboost's best error=0.1533,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:12] {1826} INFO - iteration 20, current learner rf
# [flaml.automl: 11-14 00:51:12] {2023} INFO -  at 10.4s,	estimator rf's best error=0.1436,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:12] {1826} INFO - iteration 21, current learner xgboost
# [flaml.automl: 11-14 00:51:13] {2023} INFO -  at 10.7s,	estimator xgboost's best error=0.1403,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:13] {1826} INFO - iteration 22, current learner lgbm
# [flaml.automl: 11-14 00:51:15] {2023} INFO -  at 13.3s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:15] {1826} INFO - iteration 23, current learner lgbm
# [flaml.automl: 11-14 00:51:17] {2023} INFO -  at 14.8s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:17] {1826} INFO - iteration 24, current learner extra_tree
# [flaml.automl: 11-14 00:51:17] {2023} INFO -  at 15.3s,	estimator extra_tree's best error=0.1481,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:17] {1826} INFO - iteration 25, current learner extra_tree
# [flaml.automl: 11-14 00:51:18] {2023} INFO -  at 16.0s,	estimator extra_tree's best error=0.1421,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:18] {1826} INFO - iteration 26, current learner rf
# [flaml.automl: 11-14 00:51:19] {2023} INFO -  at 16.8s,	estimator rf's best error=0.1389,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:19] {1826} INFO - iteration 27, current learner xgboost
# [flaml.automl: 11-14 00:51:19] {2023} INFO -  at 17.1s,	estimator xgboost's best error=0.1403,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:19] {1826} INFO - iteration 28, current learner xgboost
# [flaml.automl: 11-14 00:51:19] {2023} INFO -  at 17.5s,	estimator xgboost's best error=0.0971,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:19] {1826} INFO - iteration 29, current learner xgboost
# [flaml.automl: 11-14 00:51:20] {2023} INFO -  at 17.9s,	estimator xgboost's best error=0.0901,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:20] {1826} INFO - iteration 30, current learner lgbm
# [flaml.automl: 11-14 00:51:22] {2023} INFO -  at 19.8s,	estimator lgbm's best error=0.0779,	best estimator lgbm's best error=0.0779
# [flaml.automl: 11-14 00:51:22] {1826} INFO - iteration 31, current learner lgbm
# [flaml.automl: 11-14 00:51:24] {2023} INFO -  at 22.7s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:24] {1826} INFO - iteration 32, current learner rf
# [flaml.automl: 11-14 00:51:25] {2023} INFO -  at 23.5s,	estimator rf's best error=0.1389,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:25] {1826} INFO - iteration 33, current learner xgboost
# [flaml.automl: 11-14 00:51:26] {2023} INFO -  at 24.3s,	estimator xgboost's best error=0.0901,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:26] {1826} INFO - iteration 34, current learner lgbm
# [flaml.automl: 11-14 00:51:33] {2023} INFO -  at 31.5s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:33] {1826} INFO - iteration 35, current learner xgboost
# [flaml.automl: 11-14 00:51:34] {2023} INFO -  at 32.0s,	estimator xgboost's best error=0.0857,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:34] {1826} INFO - iteration 36, current learner extra_tree
# [flaml.automl: 11-14 00:51:35] {2023} INFO -  at 32.7s,	estimator extra_tree's best error=0.1421,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:35] {1826} INFO - iteration 37, current learner xgboost
# [flaml.automl: 11-14 00:51:35] {2023} INFO -  at 33.3s,	estimator xgboost's best error=0.0857,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:35] {1826} INFO - iteration 38, current learner xgboost
# [flaml.automl: 11-14 00:51:36] {2023} INFO -  at 33.8s,	estimator xgboost's best error=0.0857,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:36] {1826} INFO - iteration 39, current learner lgbm
# [flaml.automl: 11-14 00:51:37] {2023} INFO -  at 35.4s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:37] {1826} INFO - iteration 40, current learner xgboost
# [flaml.automl: 11-14 00:51:38] {2023} INFO -  at 36.1s,	estimator xgboost's best error=0.0826,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:38] {1826} INFO - iteration 41, current learner xgboost
# [flaml.automl: 11-14 00:51:39] {2023} INFO -  at 36.8s,	estimator xgboost's best error=0.0826,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:39] {1826} INFO - iteration 42, current learner lgbm
# [flaml.automl: 11-14 00:51:44] {2023} INFO -  at 42.6s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:44] {1826} INFO - iteration 43, current learner xgboost
# [flaml.automl: 11-14 00:51:46] {2023} INFO -  at 44.1s,	estimator xgboost's best error=0.0775,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:46] {1826} INFO - iteration 44, current learner extra_tree
# [flaml.automl: 11-14 00:51:47] {2023} INFO -  at 44.9s,	estimator extra_tree's best error=0.1177,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:47] {1826} INFO - iteration 45, current learner extra_tree
# [flaml.automl: 11-14 00:51:48] {2023} INFO -  at 46.0s,	estimator extra_tree's best error=0.1013,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:48] {1826} INFO - iteration 46, current learner xgboost
# [flaml.automl: 11-14 00:51:49] {2023} INFO -  at 47.2s,	estimator xgboost's best error=0.0775,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:49] {1826} INFO - iteration 47, current learner extra_tree
# [flaml.automl: 11-14 00:51:50] {2023} INFO -  at 47.9s,	estimator extra_tree's best error=0.1013,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:50] {1826} INFO - iteration 48, current learner lgbm
# [flaml.automl: 11-14 00:51:52] {2023} INFO -  at 50.0s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:52] {1826} INFO - iteration 49, current learner xgboost
# [flaml.automl: 11-14 00:51:55] {2023} INFO -  at 53.1s,	estimator xgboost's best error=0.0775,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:55] {1826} INFO - iteration 50, current learner extra_tree
# [flaml.automl: 11-14 00:51:56] {2023} INFO -  at 53.9s,	estimator extra_tree's best error=0.1013,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:56] {1826} INFO - iteration 51, current learner xgboost
# [flaml.automl: 11-14 00:51:56] {2023} INFO -  at 54.6s,	estimator xgboost's best error=0.0775,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:51:56] {1826} INFO - iteration 52, current learner xgboost
# [flaml.automl: 11-14 00:52:03] {2023} INFO -  at 60.7s,	estimator xgboost's best error=0.0756,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:52:03] {1826} INFO - iteration 53, current learner lgbm
# [flaml.automl: 11-14 00:52:04] {2023} INFO -  at 61.7s,	estimator lgbm's best error=0.0744,	best estimator lgbm's best error=0.0744
# [flaml.automl: 11-14 00:52:04] {1826} INFO - iteration 54, current learner lgbm
# [flaml.automl: 11-14 00:52:12] {2023} INFO -  at 69.9s,	estimator lgbm's best error=0.0731,	best estimator lgbm's best error=0.0731
# [flaml.automl: 11-14 00:52:12] {1826} INFO - iteration 55, current learner extra_tree
# [flaml.automl: 11-14 00:52:13] {2023} INFO -  at 71.1s,	estimator extra_tree's best error=0.0898,	best estimator lgbm's best error=0.0731
# [flaml.automl: 11-14 00:52
	best estimator lgbm's best error=0.0731
# [flaml.automl: 11-14 00:57:11] {1826} INFO - iteration 104, current learner xgboost
# [flaml.automl: 11-14 00:57:18] {2023} INFO -  at 375.8s,	estimator xgboost's best error=0.0749,	best estimator lgbm's best error=0.0731
# [flaml.automl: 11-14 00:57:18] {1826} INFO - iteration 105, current learner lgbm
# [flaml.automl: 11-14 00:57:30] {2023} INFO -  at 388.3s,	estimator lgbm's best error=0.0729,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:30] {1826} INFO - iteration 106, current learner rf
# [flaml.automl: 11-14 00:57:33] {2023} INFO -  at 391.2s,	estimator rf's best error=0.0850,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:33] {1826} INFO - iteration 107, current learner extra_tree
# [flaml.automl: 11-14 00:57:35] {2023} INFO -  at 392.7s,	estimator extra_tree's best error=0.0830,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:35] {1826} INFO - iteration 108, current learner rf
# [flaml.automl: 11-14 00:57:36] {2023} INFO -  at 394.4s,	estimator rf's best error=0.0850,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:36] {1826} INFO - iteration 109, current learner extra_tree
# [flaml.automl: 11-14 00:57:37] {2023} INFO -  at 395.3s,	estimator extra_tree's best error=0.0830,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:37] {1826} INFO - iteration 110, current learner xgboost
# [flaml.automl: 11-14 00:57:56] {2023} INFO -  at 413.9s,	estimator xgboost's best error=0.0749,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:57:56] {1826} INFO - iteration 111, current learner lgbm
# [flaml.automl: 11-14 00:58:15] {2023} INFO -  at 433.2s,	estimator lgbm's best error=0.0729,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:58:15] {1826} INFO - iteration 112, current learner extra_tree
# [flaml.automl: 11-14 00:58:16] {2023} INFO -  at 434.6s,	estimator extra_tree's best error=0.0830,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:58:16] {1826} INFO - iteration 113, current learner xgboost
# [flaml.automl: 11-14 00:58:18] {2023} INFO -  at 436.4s,	estimator xgboost's best error=0.0749,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:58:18] {1826} INFO - iteration 114, current learner extra_tree
# [flaml.automl: 11-14 00:58:20] {2023} INFO -  at 437.7s,	estimator extra_tree's best error=0.0830,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:58:20] {1826} INFO - iteration 115, current learner lgbm
# [flaml.automl: 11-14 00:58:31] {2023} INFO -  at 449.1s,	estimator lgbm's best error=0.0729,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:58:31] {1826} INFO - iteration 116, current learner lgbm
# [flaml.automl: 11-14 00:59:27] {2023} INFO -  at 505.6s,	estimator lgbm's best error=0.0729,	best estimator lgbm's best error=0.0729
# [flaml.automl: 11-14 00:59:30] {2240} INFO - retrain lgbm for 2.6s
# [flaml.automl: 11-14 00:59:30] {2247} INFO - retrained model: LGBMClassifier(colsample_bytree=0.5082885101331202,
#                learning_rate=0.025524991142201976, max_bin=127,
#                min_child_samples=8, n_estimators=604, num_leaves=92,
#                reg_alpha=0.03444328444191028, reg_lambda=0.00302017344733214,
#                verbose=-1)
# [flaml.automl: 11-14 00:59:30] {1608} INFO - fit succeeded
# [flaml.automl: 11-14 00:59:30] {1609} INFO - Time taken to find the best model: 388.34659481048584
# [flaml.automl: 11-14 00:59:30] {1620} WARNING - Time taken to find the best model is 78% of the provided time budget and not all estimators' hyperparameter search converged. Consider increasing the time budget.

# %%
print(automl.best_estimator)
print(automl.best_config)
# Out:
# lgbm
# {'n_estimators': 604, 'num_leaves': 92, 'min_child_samples': 8, 'learning_rate': 0.025524991142201976, 'log_max_bin': 7, 'colsample_bytree': 0.5082885101331202, 'reg_alpha': 0.03444328444191028, 'reg_lambda': 0.00302017344733214}

# %%
from flaml.model import LGBMEstimator

''' create a customized LightGBM learner class with your objective function '''
class MyLGBM(LGBMEstimator):
    '''LGBMEstimator with my_loss_obj as the objective function
    '''

    def __init__(self, **config):
        #super().__init__(boosting_type='dart', rate_drop=0.03, skip_drop=0.5,max_drop=70,**config)
        super().__init__(boosting_type='dart',**config)
    
    def search_space(data_size, **params):
        upper = min(32768, int(data_size))
        return {
            "num_leaves": {
                "domain": tune.lograndint(lower=4, upper=upper),
                "init_value": 4,
                "low_cost_init_value": 4,
            },
            "n_estimators": {
                "domain": tune.lograndint(lower=4, upper=upper),
                "init_value": 4,
                "low_cost_init_value": 4,
            },
            "min_child_weight": {
                "domain": tune.loguniform(lower=0.001, upper=128),
                "init_value": 1,
            },
            "learning_rate": {
                "domain": tune.loguniform(lower=1 / 1024, upper=1.0),
                "init_value": 0.1,
            },
            "subsample": {
                "domain": tune.uniform(lower=0.1, upper=1.0),
                "init_value": 1.0,
            },
            "colsample_bytree": {
                "domain": tune.uniform(lower=0.01, upper=1.0),
                "init_value": 1.0,
            },
            "reg_alpha": {
                "domain": tune.loguniform(lower=1 / 1024, upper=1024),
                "init_value": 1 / 1024,
            },
            "reg_lambda": {
                "domain": tune.loguniform(lower=1 / 1024, upper=1024),
                "init_value": 1.0,
            },
            "rate_drop": {
                "domain": tune.loguniform(lower=1 / 1024, upper=1.0),
                "init_value": 0.1,
            },
            "skip_drop": {
                "domain": tune.loguniform(lower=1 / 1024, upper=1.0),
                "init_value": 0.5,
            },
            "max_drop": {
                "domain": tune.lograndint(lower=4, upper=upper),
                "init_value": 50,
            },
        }
        
from flaml import AutoML
automl = AutoML()
automl.add_learner(learner_name='my_lgbm', learner_class=MyLGBM)
settings = {
    "time_budget": 600,  # total running time in seconds
    "estimator_list": ['my_lgbm',],  # list of ML learners; we tune lightgbm in this example
    "task": 'classification',  # task type    
}
automl.fit(X_train=train, y_train=train_target, **settings)
# Out:
# [flaml.automl: 11-14 15:37:25] {1485} INFO - Data split method: stratified
# [flaml.automl: 11-14 15:37:25] {1489} INFO - Evaluation method: holdout
# [flaml.automl: 11-14 15:37:25] {1540} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl: 11-14 15:37:25] {1577} INFO - List of ML learners in AutoML Run: ['my_lgbm']
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 0, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {1943} INFO - Estimated sufficient time budget=1852s. Estimated necessary time budget=2s.
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.5s,	estimator my_lgbm's best error=0.1872,	best estimator my_lgbm's best error=0.1872
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 1, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.5s,	estimator my_lgbm's best error=0.1872,	best estimator my_lgbm's best error=0.1872
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 2, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.6s,	estimator my_lgbm's best error=0.1653,	best estimator my_lgbm's best error=0.1653
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 3, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.7s,	estimator my_lgbm's best error=0.0854,	best estimator my_lgbm's best error=0.0854
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 4, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.7s,	estimator my_lgbm's best error=0.0854,	best estimator my_lgbm's best error=0.0854
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 5, current learner my_lgbm
# [flaml.automl: 11-14 15:37:25] {2023} INFO -  at 0.8s,	estimator my_lgbm's best error=0.0854,	best estimator my_lgbm's best error=0.0854
# [flaml.automl: 11-14 15:37:25] {1826} INFO - iteration 6, current learner my_lgbm
# [flaml.automl: 11-14 15:37:26] {2023} INFO -  at 1.2s,	estimator my_lgbm's best error=0.0854,	best estimator my_lgbm's best error=0.0854
# [flaml.automl: 11-14 15:37:26] {1826} INFO - iteration 7, current learner my_lgbm
# [flaml.automl: 11-14 15:37:26] {2023} INFO -  at 1.5s,	estimator my_lgbm's best error=0.0744,	best estimator my_lgbm's best error=0.0744
# [flaml.automl: 11-14 15:37:26] {1826} INFO - iteration 8, current learner my_lgbm
# [flaml.automl: 11-14 15:37:26] {2023} INFO -  at 1.7s,	estimator my_lgbm's best error=0.0744,	best estimator my_lgbm's best error=0.0744
# [flaml.automl: 11-14 15:37:26] {1826} INFO - iteration 9, current learner my_lgbm
# [flaml.automl: 11-14 15:37:26] {2023} INFO -  at 1.9s,	estimator my_lgbm's best error=0.0744,	best estimator my_lgbm's best error=0.0744
# [flaml.automl: 11-14 15:37:26] {1826} INFO - iteration 10, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.2s,	estimator my_lgbm's best error=0.0744,	best estimator my_lgbm's best error=0.0744
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 11, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.4s,	estimator my_lgbm's best error=0.0744,	best estimator my_lgbm's best error=0.0744
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 12, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.6s,	estimator my_lgbm's best error=0.0731,	best estimator my_lgbm's best error=0.0731
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 13, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.7s,	estimator my_lgbm's best error=0.0731,	best estimator my_lgbm's best error=0.0731
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 14, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.8s,	estimator my_lgbm's best error=0.0723,	best estimator my_lgbm's best error=0.0723
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 15, current learner my_lgbm
# [flaml.automl: 11-14 15:37:27] {2023} INFO -  at 2.9s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:27] {1826} INFO - iteration 16, current learner my_lgbm
# [flaml.automl: 11-14 15:37:28] {2023} INFO -  at 3.3s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:28] {1826} INFO - iteration 17, current learner my_lgbm
# [flaml.automl: 11-14 15:37:28] {2023} INFO -  at 3.4s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:28] {1826} INFO - iteration 18, current learner my_lgbm
# [flaml.automl: 11-14 15:37:28] {2023} INFO -  at 3.5s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:28] {1826} INFO - iteration 19, current learner my_lgbm
# [flaml.automl: 11-14 15:37:28] {2023} INFO -  at 3.7s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:28] {1826} INFO - iteration 20, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.0s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 21, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.1s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 22, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.2s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 23, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.3s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 24, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.4s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 25, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.7s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 26, current learner my_lgbm
# [flaml.automl: 11-14 15:37:29] {2023} INFO -  at 4.9s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:29] {1826} INFO - iteration 27, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.0s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 28, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.2s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 29, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.3s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 30, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.5s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 31, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.6s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 32, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.7s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 33, current learner my_lgbm
# [flaml.automl: 11-14 15:37:30] {2023} INFO -  at 5.9s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:30] {1826} INFO - iteration 34, current learner my_lgbm
# [flaml.automl: 11-14 15:37:31] {2023} INFO -  at 6.0s,	estimator my_lgbm's best error=0.0717,	best estimator my_lgbm's best error=0.0717
# [flaml.automl: 11-14 15:37:31] {1826} INFO - iteration 35, current learner my_lgbm
# [flaml.automl: 11-14 15:37:31] {2023} INFO -  at 6.5s,	estimator my_lgbm's best error=0.0715,	best estimator my_lgbm's best error=0.0715
# [flaml.automl: 11-14 15:37:31] {1826} INFO - iteration 36, current learner my_lgbm
# [flaml.automl: 11-14 15:37:31] {2023} INFO -  at 6.8s,	estimator my_lgbm's best error=0.0715,	best estimator my_lgbm's best error=0.0715
# [flaml.automl: 11-14 15:37:31] {1826} INFO - iteration 37, current learner my_lgbm
# [flaml.automl: 11-14 15:37:32] {2023} INFO -  at 7.8s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:32] {1826} INFO - iteration 38, current learner my_lgbm
# [flaml.automl: 11-14 15:37:35] {2023} INFO -  at 10.0s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:35] {1826} INFO - iteration 39, current learner my_lgbm
# [flaml.automl: 11-14 15:37:35] {2023} INFO -  at 10.4s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:35] {1826} INFO - iteration 40, current learner my_lgbm
# [flaml.automl: 11-14 15:37:37] {2023} INFO -  at 12.1s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:37] {1826} INFO - iteration 41, current learner my_lgbm
# [flaml.automl: 11-14 15:37:37] {2023} INFO -  at 12.6s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:37] {1826} INFO - iteration 42, current learner my_lgbm
# [flaml.automl: 11-14 15:37:38] {2023} INFO -  at 13.2s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:38] {1826} INFO - iteration 43, current learner my_lgbm
# [flaml.automl: 11-14 15:37:38] {2023} INFO -  at 13.9s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:38] {1826} INFO - iteration 44, current learner my_lgbm
# [flaml.automl: 11-14 15:37:39] {2023} INFO -  at 14.5s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:39] {1826} INFO - iteration 45, current learner my_lgbm
# [flaml.automl: 11-14 15:37:41] {2023} INFO -  at 16.2s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:41] {1826} INFO - iteration 46, current learner my_lgbm
# [flaml.automl: 11-14 15:37:42] {2023} INFO -  at 17.8s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:42] {1826} INFO - iteration 47, current learner my_lgbm
# [flaml.automl: 11-14 15:37:43] {2023} INFO -  at 18.4s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:43] {1826} INFO - iteration 48, current learner my_lgbm
# [flaml.automl: 11-14 15:37:43] {2023} INFO -  at 18.6s,	estimator my_lgbm's best error=0.0689,	best estimator my_lgbm's best error=0.0689
# [flaml.automl: 11-14 15:37:43] {1826} INFO - iteration 49, current learner my_lgbm
# [flaml.automl: 11-14 15:37:55] {2023} INFO -  at 30.6s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:37:55] {1826} INFO - iteration 50, current learner my_lgbm
# [flaml.automl: 11-14 15:38:00] {2023} INFO -  at 35.4s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:38:00] {1826} INFO - iteration 51, current learner my_lgbm
# [flaml.automl: 11-14 15:38:14] {2023} INFO -  at 49.3s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:38:14] {1826} INFO - iteration 52, current learner my_lgbm
# [flaml.automl: 11-14 15:38:19] {2023} INFO -  at 54.9s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:38:19] {1826} INFO - iteration 53, current learner my_lgbm
# [flaml.automl: 11-14 15:38:39] {2023} INFO -  at 74.3s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:38:39] {1826} INFO - iteration 54, current learner my_lgbm
# [flaml.automl: 11-14 15:39:55] {2023} INFO -  at 150.1s,	estimator my_lgbm's best error=0.0681,	best estimator my_lgbm's best error=0.0681
# [flaml.automl: 11-14 15:40:09] {2240} INFO - retrain my_lgbm for 14.5s
# [flaml.automl: 11-14 15:40:09] {2247} INFO - retrained model: LGBMClassifier(boosting_type='dart', learning_rate=0.22368731017154514,
#                max_drop=31, min_child_weight=1.004679272546367,
#                n_estimators=741, num_leaves=24, rate_drop=0.07714889941205541,
#                reg_alpha=0.06399390812880226, reg_lambda=0.03728622212028055,
#                skip_drop=0.23059567262520608, subsample=0.96077166211253,
#                verbose=-1)
# [flaml.automl: 11-14 15:40:09] {1608} INFO - fit succeeded
# [flaml.automl: 11-14 15:40:09] {1609} INFO - Time taken to find the best model: 30.575019359588623

# %%
preds = automl.predict(test)
submission = pd.DataFrame({'Id': keys, 'Fault':preds})
submission.to_csv('sample_submission.csv',index=False)
# accuracy_score(test_target, preds)
